# %%
# Acesso à raiz do projeto

import sys
import os

# Caminho até a raiz do projeto
sys.path.append(os.path.abspath("../../"))

# %%
# Importação das bibliotecas necessárias

from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from modulos.gerais import exibir_resultado, exibir_relatorio_de_classificacao, preparar_digits
from modulos.naive_bayes import executar_naive_bayes

# %%
# Importação e exploração dos dados
digits = load_digits()
X, y, feature_names, target_names = preparar_digits(digits)

target_names = [str(nome) for nome in digits.target_names]

# Divisão em Treino (70%) e Teste (30%) com semente fixa para reprodutibilidade
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=13, stratify=y
)

# %%
(y_pred_gnb, acuracia_gaussian, precisao_gaussian, revocacao_gaussian,
f1_gaussian) = executar_naive_bayes(X_train, y_train, X_test, y_test)

# %%
# Exibição dos resultados das métricas avaliadas usando Naive Bayes com Digits
exibir_resultado(
    acuracia_gaussian, precisao_gaussian,
    revocacao_gaussian, f1_gaussian,
    "NAIVE BAYES"
)
# Out:
# ==================================================
# MÉTRICAS DE AVALIAÇÃO - NAIVE BAYES
# ==================================================
# Acurácia:  0.8148
# Precisão:  0.8500
# Revocação: 0.8138
# F1-Score:  0.8172
# ==================================================

# %%
# Exibição do relatório de classificação do Naive Bayes com Digits
exibir_relatorio_de_classificacao(y_test, y_pred_gnb, digits)
# Out:
# ==================== RELATÓRIO DE CLASSIFICAÇÃO ====================
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        54
#            1       0.62      0.89      0.73        55
#            2       0.97      0.60      0.74        53
#            3       0.91      0.75      0.82        55
#            4       0.96      0.80      0.87        54
#            5       0.89      0.89      0.89        55
#            6       0.98      1.00      0.99        54
#            7       0.70      0.94      0.80        54
#            8       0.53      0.69      0.60        52
#            9       0.94      0.61      0.74        54
#
#     accuracy                           0.81       540
#    macro avg       0.85      0.81      0.82       540
# weighted avg       0.85      0.81      0.82       540
#
# =====================================================================
